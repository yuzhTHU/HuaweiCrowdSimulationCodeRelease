# %%
# [ETH|train|I|Feb25 18:02:40|0:27:45.837064] [Final Test] Overall on ETH datasets: Accuracy=92.66%, ADE=0.4631, FDE=1.0181, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=1.36% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.01%), Collision-Ped2=10.21%, Collision-Veh2=nan%, Collision-Map2=0.02%, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=18.37ms (FPS=54.44 Hz)
# [ETH|train|I|Feb25 18:02:40|0:27:45.837693] [Final Test] Overall on GC datasets: Accuracy=80.10%, ADE=0.6298, FDE=1.2764, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-1.73% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=0.26% (+13.23%), Collision-Ped2=4.47%, Collision-Veh2=nan%, Collision-Map2=2.93%, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=21.64ms (FPS=46.22 Hz)
# [ETH|train|I|Feb25 18:02:40|0:27:45.838249] [Final Test] Overall on SDD datasets: Accuracy=86.81%, ADE=0.6371, FDE=1.2717, X_ERROR (normal)=0.7714, Y_ERROR (tangential)=1.0105, Collision-Ped=0.08% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.17%, Collision-Veh2=nan%, Collision-Map2=nan%, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=20.08ms (FPS=49.80 Hz)
# [ETH|train|I|Feb25 18:02:40|0:27:45.840141] [Final Test] Overall on WayMo datasets: Accuracy=90.50%, ADE=0.5071, FDE=1.0942, X_ERROR (normal)=0.3147, Y_ERROR (tangential)=0.3253, Collision-Ped=-2.18% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.49%, Collision-Veh2=nan%, Collision-Map2=0.00%, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=18.82ms (FPS=53.14 Hz)

# [UCY|train|I|Feb25 19:22:05|1:47:05.971539] [Final Test] Overall on ETH datasets: Accuracy=93.65%, ADE=0.4009, FDE=0.8296, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=1.26% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.03% (+0.01%), Collision-Ped2=10.06%, Collision-Veh2=nan%, Collision-Map2=0.06%, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=17.96ms (FPS=55.67 Hz)
# [UCY|train|I|Feb25 19:22:05|1:47:05.972198] [Final Test] Overall on GC datasets: Accuracy=89.40%, ADE=0.3356, FDE=0.6491, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.41% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=0.25% (+13.23%), Collision-Ped2=4.98%, Collision-Veh2=nan%, Collision-Map2=3.34%, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=20.97ms (FPS=47.68 Hz)
# [UCY|train|I|Feb25 19:22:05|1:47:05.972596] [Final Test] Overall on SDD datasets: Accuracy=90.46%, ADE=0.4607, FDE=0.9011, X_ERROR (normal)=0.6158, Y_ERROR (tangential)=0.8988, Collision-Ped=0.49% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.35%, Collision-Veh2=nan%, Collision-Map2=nan%, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=19.45ms (FPS=51.40 Hz)
# [UCY|train|I|Feb25 19:22:05|1:47:05.973774] [Final Test] Overall on WayMo datasets: Accuracy=93.18%, ADE=0.3643, FDE=0.7668, X_ERROR (normal)=0.2374, Y_ERROR (tangential)=0.2308, Collision-Ped=-0.97% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.66%, Collision-Veh2=nan%, Collision-Map2=0.00%, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=18.27ms (FPS=54.75 Hz)

# [GC|train|I|Feb25 21:03:14|3:28:12.496303] [Final Test] Overall on ETH datasets: Accuracy=94.55%, ADE=0.3441, FDE=0.6692, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=1.22% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.02% (+0.01%), Collision-Ped2=9.24%, Collision-Veh2=nan%, Collision-Map2=0.05%, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=13.24ms (FPS=75.50 Hz)
# [GC|train|I|Feb25 21:03:14|3:28:12.496780] [Final Test] Overall on GC datasets: Accuracy=93.65%, ADE=0.2010, FDE=0.3715, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.82% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=0.01% (+13.23%), Collision-Ped2=2.99%, Collision-Veh2=nan%, Collision-Map2=0.56%, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=13.54ms (FPS=73.83 Hz)
# [GC|train|I|Feb25 21:03:14|3:28:12.497248] [Final Test] Overall on SDD datasets: Accuracy=91.27%, ADE=0.4216, FDE=0.8064, X_ERROR (normal)=0.6345, Y_ERROR (tangential)=0.9488, Collision-Ped=0.69% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.41%, Collision-Veh2=nan%, Collision-Map2=nan%, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=11.97ms (FPS=83.52 Hz)
# [GC|train|I|Feb25 21:03:14|3:28:12.498426] [Final Test] Overall on WayMo datasets: Accuracy=93.22%, ADE=0.3619, FDE=0.7287, X_ERROR (normal)=0.2235, Y_ERROR (tangential)=0.2416, Collision-Ped=-0.80% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.84%, Collision-Veh2=nan%, Collision-Map2=0.00%, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=13.75ms (FPS=72.75 Hz)

# [SDD|train|I|Feb26 01:28:23|7:53:18.972524] [Final Test] Overall on ETH datasets: Accuracy=94.91%, ADE=0.3210, FDE=0.7127, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=1.04% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.02% (+0.01%), Collision-Ped2=8.34%, Collision-Veh2=nan%, Collision-Map2=0.05%, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=9.87ms (FPS=101.32 Hz)
# [SDD|train|I|Feb26 01:28:23|7:53:18.973029] [Final Test] Overall on GC datasets: Accuracy=92.14%, ADE=0.2489, FDE=0.4545, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.74% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=1.34% (+13.23%), Collision-Ped2=4.52%, Collision-Veh2=nan%, Collision-Map2=4.22%, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=11.06ms (FPS=90.44 Hz)
# [SDD|train|I|Feb26 01:28:23|7:53:18.973654] [Final Test] Overall on SDD datasets: Accuracy=93.72%, ADE=0.3035, FDE=0.5727, X_ERROR (normal)=0.5386, Y_ERROR (tangential)=0.8538, Collision-Ped=0.53% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.06%, Collision-Veh2=nan%, Collision-Map2=nan%, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=10.01ms (FPS=99.88 Hz)
# [SDD|train|I|Feb26 01:28:23|7:53:18.974980] [Final Test] Overall on WayMo datasets: Accuracy=94.04%, ADE=0.3183, FDE=0.6271, X_ERROR (normal)=0.1906, Y_ERROR (tangential)=0.2038, Collision-Ped=-0.66% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.44%, Collision-Veh2=nan%, Collision-Map2=0.00%, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=10.04ms (FPS=99.56 Hz)

# [WayMo|train|I|Feb26 04:12:34|10:37:24.233600] [Final Test] Overall on ETH datasets: Accuracy=93.22%, ADE=0.4278, FDE=0.8877, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=1.41% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.03% (+0.01%), Collision-Ped2=9.44%, Collision-Veh2=nan%, Collision-Map2=0.06%, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=19.69ms (FPS=50.77 Hz)
# [WayMo|train|I|Feb26 04:12:34|10:37:24.234156] [Final Test] Overall on GC datasets: Accuracy=89.91%, ADE=0.3194, FDE=0.5833, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-0.30% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=1.81% (+13.23%), Collision-Ped2=4.97%, Collision-Veh2=nan%, Collision-Map2=5.35%, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=20.26ms (FPS=49.37 Hz)
# [WayMo|train|I|Feb26 04:12:34|10:37:24.234726] [Final Test] Overall on SDD datasets: Accuracy=90.99%, ADE=0.4353, FDE=0.8135, X_ERROR (normal)=0.6506, Y_ERROR (tangential)=0.9509, Collision-Ped=0.53% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.31%, Collision-Veh2=nan%, Collision-Map2=nan%, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=21.18ms (FPS=47.21 Hz)
# [WayMo|train|I|Feb26 04:12:34|10:37:24.236039] [Final Test] Overall on WayMo datasets: Accuracy=94.89%, ADE=0.2728, FDE=0.5609, X_ERROR (normal)=0.1680, Y_ERROR (tangential)=0.1732, Collision-Ped=-0.18% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.78%, Collision-Veh2=nan%, Collision-Map2=0.00%, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=24.99ms (FPS=40.01 Hz)

# [All|train|I|Feb26 10:32:15|16:57:01.729863] [Final Test] Overall on ETH datasets: Accuracy=94.09%, ADE=0.3730, FDE=0.7668, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.43% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.02% (+0.01%), Collision-Ped2=9.07%, Collision-Veh2=nan%, Collision-Map2=0.05%, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=18.20ms (FPS=54.94 Hz)
# [All|train|I|Feb26 10:32:15|16:57:01.730626] [Final Test] Overall on GC datasets: Accuracy=91.92%, ADE=0.2559, FDE=0.4773, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-0.11% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=-1.27% (+13.23%), Collision-Ped2=4.42%, Collision-Veh2=nan%, Collision-Map2=2.50%, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=16.01ms (FPS=62.46 Hz)
# [All|train|I|Feb26 10:32:15|16:57:01.731475] [Final Test] Overall on SDD datasets: Accuracy=92.82%, ADE=0.3469, FDE=0.6467, X_ERROR (normal)=0.5759, Y_ERROR (tangential)=0.8672, Collision-Ped=0.52% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.22%, Collision-Veh2=nan%, Collision-Map2=nan%, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=17.39ms (FPS=57.49 Hz)
# [All|train|I|Feb26 10:32:15|16:57:01.733058] [Final Test] Overall on WayMo datasets: Accuracy=95.58%, ADE=0.2359, FDE=0.4750, X_ERROR (normal)=0.1421, Y_ERROR (tangential)=0.1487, Collision-Ped=-0.00% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.46%, Collision-Veh2=nan%, Collision-Map2=0.00%, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=18.58ms (FPS=53.81 Hz)

# %%
[ETH|test|N|Feb26 11:01:15|0:05:10.653052] Test Accuracy=87.05% (unweighted=89.99%), at epoch 581. ADE=0.6029, FDE=1.2270, X_ERROR (normal)=0.3444, Y_ERROR (tangential)=0.3865, Collision-Ped=-1.01% (+7.91%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=3.10%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.8314, AvgLen=4.6560, Loss=0.4173, PedNum=11.4, VehNum=5.1, RolloutTime=13.47ms (FPS=74.22 Hz)
[UCY|test|N|Feb26 11:01:28|0:05:11.656857] Test Accuracy=91.22% (unweighted=92.98%), at epoch 1341. ADE=0.4088, FDE=0.8098, X_ERROR (normal)=0.2653, Y_ERROR (tangential)=0.2833, Collision-Ped=0.22% (+7.91%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=3.24%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.6528, AvgLen=4.6560, Loss=0.3165, PedNum=11.4, VehNum=5.1, RolloutTime=13.32ms (FPS=75.05 Hz)
[GC|test|N|Feb26 11:01:31|0:05:08.881839] Test Accuracy=92.12% (unweighted=92.98%), at epoch 901. ADE=0.3670, FDE=0.7067, X_ERROR (normal)=0.2547, Y_ERROR (tangential)=0.3002, Collision-Ped=0.35% (+7.91%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=3.02%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.7225, AvgLen=4.6560, Loss=0.4277, PedNum=11.4, VehNum=5.1, RolloutTime=13.23ms (FPS=75.61 Hz)
[SDD|test|N|Feb26 11:01:41|0:05:11.014678] Test Accuracy=93.66% (unweighted=93.85%), at epoch 911. ADE=0.2954, FDE=0.5656, X_ERROR (normal)=0.2156, Y_ERROR (tangential)=0.2540, Collision-Ped=0.52% (+7.91%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=3.06%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.5230, AvgLen=4.6560, Loss=0.3503, PedNum=11.4, VehNum=5.1, RolloutTime=13.31ms (FPS=75.14 Hz)
[WayMo|test|N|Feb26 11:07:29|0:10:13.857868] Test Accuracy=91.84% (unweighted=94.52%), at epoch 371. ADE=0.3801, FDE=0.7218, X_ERROR (normal)=0.2071, Y_ERROR (tangential)=0.2372, Collision-Ped=0.27% (+7.91%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=3.34%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4394, AvgLen=4.6560, Loss=0.2795, PedNum=11.4, VehNum=5.1, RolloutTime=27.59ms (FPS=36.24 Hz)
[All|test|N|Feb26 11:07:52|0:10:18.330157] Test Accuracy=93.37% (unweighted=95.35%), at epoch 281. ADE=0.3085, FDE=0.5848, X_ERROR (normal)=0.1745, Y_ERROR (tangential)=0.2079, Collision-Ped=0.34% (+7.91%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=3.11%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.5764, AvgLen=4.6560, Loss=0.3301, PedNum=11.4, VehNum=5.1, RolloutTime=27.21ms (FPS=36.75 Hz)

# %% [markdown]
# [ETH|test|I|Feb26 11:01:15|0:05:10.653761] Overall on ETH datasets: Accuracy=92.71%, ADE=0.4600, FDE=1.0162, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=1.56% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.01%), Collision-Ped2=10.37%, Collision-Veh2=nan%, Collision-Map2=0.02%, APD=0.6808, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=11.78ms (FPS=84.91 Hz)
# [ETH|test|I|Feb26 11:01:15|0:05:10.654319] Overall on GC datasets: Accuracy=80.08%, ADE=0.6306, FDE=1.2792, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-1.73% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=0.30% (+13.23%), Collision-Ped2=4.48%, Collision-Veh2=nan%, Collision-Map2=2.93%, APD=0.6630, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=19.65ms (FPS=50.88 Hz)
# [ETH|test|I|Feb26 11:01:15|0:05:10.654781] Overall on SDD datasets: Accuracy=86.82%, ADE=0.6368, FDE=1.2711, X_ERROR (normal)=0.7616, Y_ERROR (tangential)=1.0002, Collision-Ped=0.07% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.15%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.8666, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=13.35ms (FPS=74.93 Hz)
# [ETH|test|I|Feb26 11:01:15|0:05:10.655206] Overall on UCY datasets: Accuracy=87.51%, ADE=0.5199, FDE=1.1052, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-7.64% (+30.87%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=12.05%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.8197, AvgLen=4.1614, PedNum=11.7884, VehNum=0.0000, RolloutTime=10.69ms (FPS=93.52 Hz)
# [ETH|test|I|Feb26 11:01:15|0:05:10.656397] Overall on WayMo datasets: Accuracy=90.45%, ADE=0.5102, FDE=1.0996, X_ERROR (normal)=0.3079, Y_ERROR (tangential)=0.3328, Collision-Ped=-2.21% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.48%, Collision-Veh2=nan%, Collision-Map2=0.00%, APD=0.8911, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=13.51ms (FPS=74.02 Hz)
#
# [UCY|test|I|Feb26 11:01:28|0:05:11.657617] Overall on ETH datasets: Accuracy=93.69%, ADE=0.3984, FDE=0.8157, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=1.53% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.04% (+0.01%), Collision-Ped2=10.18%, Collision-Veh2=nan%, Collision-Map2=0.07%, APD=0.6552, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=14.96ms (FPS=66.84 Hz)
# [UCY|test|I|Feb26 11:01:28|0:05:11.658081] Overall on GC datasets: Accuracy=89.41%, ADE=0.3353, FDE=0.6480, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.41% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=0.28% (+13.23%), Collision-Ped2=4.97%, Collision-Veh2=nan%, Collision-Map2=3.35%, APD=0.6515, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=18.80ms (FPS=53.20 Hz)
# [UCY|test|I|Feb26 11:01:28|0:05:11.658554] Overall on SDD datasets: Accuracy=90.46%, ADE=0.4609, FDE=0.9028, X_ERROR (normal)=0.6273, Y_ERROR (tangential)=0.9170, Collision-Ped=0.45% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.33%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.6778, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=13.46ms (FPS=74.32 Hz)
# [UCY|test|I|Feb26 11:01:28|0:05:11.659085] Overall on UCY datasets: Accuracy=94.94%, ADE=0.2106, FDE=0.4212, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.38% (+30.87%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=11.04%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.3882, AvgLen=4.1614, PedNum=11.7884, VehNum=0.0000, RolloutTime=17.16ms (FPS=58.26 Hz)
# [UCY|test|I|Feb26 11:01:28|0:05:11.660481] Overall on WayMo datasets: Accuracy=93.17%, ADE=0.3650, FDE=0.7672, X_ERROR (normal)=0.2336, Y_ERROR (tangential)=0.2279, Collision-Ped=-1.01% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.62%, Collision-Veh2=nan%, Collision-Map2=0.00%, APD=0.6553, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=13.25ms (FPS=75.48 Hz)
#
# [GC|test|I|Feb26 11:01:31|0:05:08.882657] Overall on ETH datasets: Accuracy=94.58%, ADE=0.3422, FDE=0.6658, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=1.40% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.02% (+0.01%), Collision-Ped2=9.38%, Collision-Veh2=nan%, Collision-Map2=0.05%, APD=0.7612, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=18.91ms (FPS=52.89 Hz)
# [GC|test|I|Feb26 11:01:31|0:05:08.883364] Overall on GC datasets: Accuracy=93.63%, ADE=0.2015, FDE=0.3722, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.79% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=0.01% (+13.23%), Collision-Ped2=2.95%, Collision-Veh2=nan%, Collision-Map2=0.57%, APD=0.3443, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=17.12ms (FPS=58.40 Hz)
# [GC|test|I|Feb26 11:01:31|0:05:08.883877] Overall on SDD datasets: Accuracy=91.24%, ADE=0.4230, FDE=0.8085, X_ERROR (normal)=0.6337, Y_ERROR (tangential)=0.9801, Collision-Ped=0.68% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.41%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.7759, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=13.24ms (FPS=75.54 Hz)
# [GC|test|I|Feb26 11:01:31|0:05:08.884334] Overall on UCY datasets: Accuracy=93.54%, ADE=0.2688, FDE=0.5573, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-0.65% (+30.87%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=12.02%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.6365, AvgLen=4.1614, PedNum=11.7884, VehNum=0.0000, RolloutTime=16.31ms (FPS=61.30 Hz)
# [GC|test|I|Feb26 11:01:31|0:05:08.885829] Overall on WayMo datasets: Accuracy=93.20%, ADE=0.3632, FDE=0.7197, X_ERROR (normal)=0.2216, Y_ERROR (tangential)=0.2408, Collision-Ped=-0.99% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.72%, Collision-Veh2=nan%, Collision-Map2=0.00%, APD=0.9082, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=13.15ms (FPS=76.03 Hz)
#
# [SDD|test|I|Feb26 11:01:41|0:05:11.015617] Overall on ETH datasets: Accuracy=94.87%, ADE=0.3238, FDE=0.7191, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.98% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.02% (+0.01%), Collision-Ped2=8.27%, Collision-Veh2=nan%, Collision-Map2=0.05%, APD=0.5649, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=14.91ms (FPS=67.06 Hz)
# [SDD|test|I|Feb26 11:01:41|0:05:11.016447] Overall on GC datasets: Accuracy=92.15%, ADE=0.2485, FDE=0.4540, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.71% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=1.29% (+13.23%), Collision-Ped2=4.51%, Collision-Veh2=nan%, Collision-Map2=4.19%, APD=0.4739, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=15.39ms (FPS=64.97 Hz)
# [SDD|test|I|Feb26 11:01:41|0:05:11.017113] Overall on SDD datasets: Accuracy=93.71%, ADE=0.3038, FDE=0.5712, X_ERROR (normal)=0.5473, Y_ERROR (tangential)=0.8582, Collision-Ped=0.54% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.06%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.5223, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=13.68ms (FPS=73.10 Hz)
# [SDD|test|I|Feb26 11:01:41|0:05:11.017760] Overall on UCY datasets: Accuracy=93.78%, ADE=0.2589, FDE=0.5476, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=2.96% (+30.87%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=13.31%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4137, AvgLen=4.1614, PedNum=11.7884, VehNum=0.0000, RolloutTime=20.72ms (FPS=48.27 Hz)
# [SDD|test|I|Feb26 11:01:41|0:05:11.019181] Overall on WayMo datasets: Accuracy=94.06%, ADE=0.3175, FDE=0.6320, X_ERROR (normal)=0.1866, Y_ERROR (tangential)=0.2012, Collision-Ped=-0.61% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.46%, Collision-Veh2=nan%, Collision-Map2=0.00%, APD=0.6001, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=13.18ms (FPS=75.84 Hz)
#
# [WayMo|test|I|Feb26 11:07:29|0:10:13.858429] Overall on ETH datasets: Accuracy=93.21%, ADE=0.4283, FDE=0.8861, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=1.31% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.02% (+0.01%), Collision-Ped2=9.39%, Collision-Veh2=nan%, Collision-Map2=0.06%, APD=0.4666, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=29.52ms (FPS=33.88 Hz)
# [WayMo|test|I|Feb26 11:07:29|0:10:13.858817] Overall on GC datasets: Accuracy=89.91%, ADE=0.3193, FDE=0.5822, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-0.36% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=1.82% (+13.23%), Collision-Ped2=4.94%, Collision-Veh2=nan%, Collision-Map2=5.34%, APD=0.3935, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=29.31ms (FPS=34.12 Hz)
# [WayMo|test|I|Feb26 11:07:29|0:10:13.859181] Overall on SDD datasets: Accuracy=91.01%, ADE=0.4345, FDE=0.8107, X_ERROR (normal)=0.6621, Y_ERROR (tangential)=0.9523, Collision-Ped=0.53% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.31%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4437, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=27.94ms (FPS=35.79 Hz)
# [WayMo|test|I|Feb26 11:07:29|0:10:13.859556] Overall on UCY datasets: Accuracy=93.01%, ADE=0.2907, FDE=0.6027, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.32% (+30.87%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=13.06%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4158, AvgLen=4.1614, PedNum=11.7884, VehNum=0.0000, RolloutTime=29.31ms (FPS=34.12 Hz)
# [WayMo|test|I|Feb26 11:07:29|0:10:13.860638] Overall on WayMo datasets: Accuracy=94.90%, ADE=0.2723, FDE=0.5609, X_ERROR (normal)=0.1674, Y_ERROR (tangential)=0.1747, Collision-Ped=-0.23% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.70%, Collision-Veh2=nan%, Collision-Map2=0.00%, APD=0.4702, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=27.55ms (FPS=36.30 Hz)
#
# [All|test|I|Feb26 11:07:52|0:10:18.331247] Overall on ETH datasets: Accuracy=94.02%, ADE=0.3770, FDE=0.7825, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.30% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.03% (+0.01%), Collision-Ped2=8.97%, Collision-Veh2=nan%, Collision-Map2=0.06%, APD=0.9388, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=29.70ms (FPS=33.67 Hz)
# [All|test|I|Feb26 11:07:52|0:10:18.332042] Overall on GC datasets: Accuracy=91.93%, ADE=0.2555, FDE=0.4769, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-0.07% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=-1.25% (+13.23%), Collision-Ped2=4.43%, Collision-Veh2=nan%, Collision-Map2=2.53%, APD=0.5925, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=27.50ms (FPS=36.36 Hz)
# [All|test|I|Feb26 11:07:52|0:10:18.332799] Overall on SDD datasets: Accuracy=92.80%, ADE=0.3479, FDE=0.6491, X_ERROR (normal)=0.5603, Y_ERROR (tangential)=0.8791, Collision-Ped=0.51% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.19%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.6202, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=27.90ms (FPS=35.85 Hz)
# [All|test|I|Feb26 11:07:52|0:10:18.333438] Overall on UCY datasets: Accuracy=94.14%, ADE=0.2441, FDE=0.4907, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.95% (+30.87%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=12.74%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4872, AvgLen=4.1614, PedNum=11.7884, VehNum=0.0000, RolloutTime=32.80ms (FPS=30.49 Hz)
# [All|test|I|Feb26 11:07:52|0:10:18.335110] Overall on WayMo datasets: Accuracy=95.63%, ADE=0.2335, FDE=0.4660, X_ERROR (normal)=0.1408, Y_ERROR (tangential)=0.1492, Collision-Ped=-0.05% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.42%, Collision-Veh2=nan%, Collision-Map2=0.00%, APD=0.3885, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=27.10ms (FPS=36.89 Hz)

# %%
[All|test|N|Feb26 11:07:52|0:10:18.330157] Test Accuracy=93.37% (unweighted=95.35%), at epoch 281. ADE=0.3085, FDE=0.5848, X_ERROR (normal)=0.1745, Y_ERROR (tangential)=0.2079, Collision-Ped=0.34% (+7.91%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=3.11%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.5764, AvgLen=4.6560, Loss=0.3301, PedNum=11.4, VehNum=5.1, RolloutTime=27.21ms (FPS=36.75 Hz)
[All|test|I|Feb26 11:07:52|0:10:18.331247] Overall on ETH datasets: Accuracy=94.02%, ADE=0.3770, FDE=0.7825, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.30% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.03% (+0.01%), Collision-Ped2=8.97%, Collision-Veh2=nan%, Collision-Map2=0.06%, APD=0.9388, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=29.70ms (FPS=33.67 Hz)
[All|test|I|Feb26 11:07:52|0:10:18.332042] Overall on GC datasets: Accuracy=91.93%, ADE=0.2555, FDE=0.4769, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-0.07% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=-1.25% (+13.23%), Collision-Ped2=4.43%, Collision-Veh2=nan%, Collision-Map2=2.53%, APD=0.5925, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=27.50ms (FPS=36.36 Hz)
[All|test|I|Feb26 11:07:52|0:10:18.332799] Overall on SDD datasets: Accuracy=92.80%, ADE=0.3479, FDE=0.6491, X_ERROR (normal)=0.5603, Y_ERROR (tangential)=0.8791, Collision-Ped=0.51% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=1.19%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.6202, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=27.90ms (FPS=35.85 Hz)
[All|test|I|Feb26 11:07:52|0:10:18.333438] Overall on UCY datasets: Accuracy=94.14%, ADE=0.2441, FDE=0.4907, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=0.95% (+30.87%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=12.74%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4872, AvgLen=4.1614, PedNum=11.7884, VehNum=0.0000, RolloutTime=32.80ms (FPS=30.49 Hz)
[All|test|I|Feb26 11:07:52|0:10:18.335110] Overall on WayMo datasets: Accuracy=95.63%, ADE=0.2335, FDE=0.4660, X_ERROR (normal)=0.1408, Y_ERROR (tangential)=0.1492, Collision-Ped=-0.05% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.42%, Collision-Veh2=nan%, Collision-Map2=0.00%, APD=0.3885, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=27.10ms (FPS=36.89 Hz)

[All|calibrate_optune|N|Feb26 15:17:55|3:45:34.356946] Test Accuracy=92.09% (unweighted=94.72%), at epoch 0. ADE=0.3681, FDE=0.7000, X_ERROR (normal)=0.2092, Y_ERROR (tangential)=0.2361, Collision-Ped=-2.18% (+7.91%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=2.68%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4329, AvgLen=4.6560, Loss=0.4092, PedNum=11.4, VehNum=5.1, RolloutTime=15.67ms (FPS=63.83 Hz)
[All|calibrate_optune|I|Feb26 15:17:55|3:45:34.357899] [Final Test] Overall on ETH datasets: Accuracy=94.32%, ADE=0.3586, FDE=0.6900, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-0.88% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.03% (+0.01%), Collision-Ped2=8.03%, Collision-Veh2=nan%, Collision-Map2=0.06%, APD=0.6818, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=13.79ms (FPS=72.50 Hz)
[All|calibrate_optune|I|Feb26 15:17:55|3:45:34.358631] [Final Test] Overall on GC datasets: Accuracy=91.60%, ADE=0.2658, FDE=0.4738, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-7.86% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=-1.84% (+13.23%), Collision-Ped2=3.91%, Collision-Veh2=nan%, Collision-Map2=1.70%, APD=0.5297, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=16.77ms (FPS=59.65 Hz)
[All|calibrate_optune|I|Feb26 15:17:55|3:45:34.359167] [Final Test] Overall on SDD datasets: Accuracy=91.03%, ADE=0.4333, FDE=0.8242, X_ERROR (normal)=0.6364, Y_ERROR (tangential)=0.9424, Collision-Ped=-0.20% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=0.95%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4223, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=15.51ms (FPS=64.46 Hz)
[All|calibrate_optune|I|Feb26 15:17:55|3:45:34.359821] [Final Test] Overall on UCY datasets: Accuracy=93.01%, ADE=0.2910, FDE=0.5773, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-6.72% (+30.87%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=10.40%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4679, AvgLen=4.1614, PedNum=11.7884, VehNum=0.0000, RolloutTime=14.23ms (FPS=70.27 Hz)
[All|calibrate_optune|I|Feb26 15:17:55|3:45:34.361399] [Final Test] Overall on WayMo datasets: Accuracy=95.02%, ADE=0.2660, FDE=0.5247, X_ERROR (normal)=0.1718, Y_ERROR (tangential)=0.1744, Collision-Ped=-2.43% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.13%, Collision-Veh2=nan%, Collision-Map2=0.00%, APD=0.3333, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=15.70ms (FPS=63.71 Hz)

[All@ETH|calibrate_optune|N|Feb26 13:41:40|0:05:05.476558] Test Accuracy=94.42% (unweighted=94.43%), at epoch 0. ADE=0.3519, FDE=0.6817, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-0.94% (+12.56%), Collision-Veh=nan% (+nan%), Collision-Map=0.04% (+0.01%), Collision-Ped2=8.01%, Collision-Veh2=nan%, Collision-Map2=0.08%, APD=0.7476, AvgLen=6.3098, Loss=1.0361, PedNum=7.7, VehNum=0.0, RolloutTime=17.01ms (FPS=58.80 Hz)
[All@UCY|calibrate_optune|N|Feb26 14:02:39|0:25:23.132693] Test Accuracy=92.91% (unweighted=92.89%), at epoch 0. ADE=0.2951, FDE=0.5906, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-6.02% (+30.87%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=10.58%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4291, AvgLen=4.1614, Loss=0.1844, PedNum=11.8, VehNum=0.0, RolloutTime=31.30ms (FPS=31.95 Hz)
[All@GC|calibrate_optune|N|Feb26 14:49:10|1:11:50.533073] Test Accuracy=91.51% (unweighted=91.51%), at epoch 0. ADE=0.2687, FDE=0.4830, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-7.75% (+17.76%), Collision-Veh=nan% (+nan%), Collision-Map=-1.74% (+13.23%), Collision-Ped2=3.88%, Collision-Veh2=nan%, Collision-Map2=1.53%, APD=0.4895, AvgLen=3.1655, Loss=0.2159, PedNum=44.0, VehNum=0.0, RolloutTime=24.97ms (FPS=40.05 Hz)
[All@SDD|calibrate_optune|N|Feb26 15:50:07|2:12:43.183287] Test Accuracy=91.13% (unweighted=85.98%), at epoch 0. ADE=0.4285, FDE=0.8148, X_ERROR (normal)=0.6267, Y_ERROR (tangential)=0.9644, Collision-Ped=-0.20% (+1.86%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=0.94%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4246, AvgLen=4.8309, Loss=0.5217, PedNum=4.3, VehNum=7.6, RolloutTime=12.10ms (FPS=82.64 Hz)
[All@WayMo|calibrate_optune|N|Feb26 15:41:36|2:04:08.425154] Test Accuracy=95.28% (unweighted=95.24%), at epoch 0. ADE=0.2520, FDE=0.4941, X_ERROR (normal)=0.1616, Y_ERROR (tangential)=0.1644, Collision-Ped=-2.28% (+11.37%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=4.14%, Collision-Veh2=nan%, Collision-Map2=0.00%, APD=0.3470, AvgLen=5.3405, Loss=0.1746, PedNum=6.4, VehNum=3.8, RolloutTime=12.71ms (FPS=78.70 Hz)

# %%
[20260226_test_193027_DL4|test|I|Feb26 19:36:24|0:05:56.981192] Overall on ETH datasets: Accuracy=94.02%, ADE=0.3770, FDE=0.7818, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=1.34% (+1.22%), Collision-Veh=nan% (+nan%), Collision-Map=0.01% (+0.01%), Collision-Ped2=2.52%, Collision-Veh2=nan%, Collision-Map2=0.04%, APD=0.9412, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=17.69ms (FPS=56.52 Hz)
[20260226_test_193027_DL4|test|I|Feb26 19:36:24|0:05:56.981952] Overall on GC datasets: Accuracy=91.91%, ADE=0.2561, FDE=0.4781, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-2.65% (+9.78%), Collision-Veh=nan% (+nan%), Collision-Map=-1.28% (+13.23%), Collision-Ped2=1.46%, Collision-Veh2=nan%, Collision-Map2=2.50%, APD=0.5926, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=17.86ms (FPS=56.00 Hz)
[20260226_test_193027_DL4|test|I|Feb26 19:36:24|0:05:56.982519] Overall on SDD datasets: Accuracy=92.79%, ADE=0.3485, FDE=0.6511, X_ERROR (normal)=0.5821, Y_ERROR (tangential)=0.8887, Collision-Ped=0.22% (+0.38%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=0.41%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.6203, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=16.26ms (FPS=61.50 Hz)
[20260226_test_193027_DL4|test|I|Feb26 19:36:24|0:05:56.983094] Overall on UCY datasets: Accuracy=94.17%, ADE=0.2424, FDE=0.4812, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=4.17% (+0.82%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=4.85%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4852, AvgLen=4.1614, PedNum=11.7884, VehNum=0.0000, RolloutTime=16.58ms (FPS=60.30 Hz)
[20260226_test_193027_DL4|test|I|Feb26 19:36:24|0:05:56.984874] Overall on WayMo datasets: Accuracy=95.63%, ADE=0.2334, FDE=0.4661, X_ERROR (normal)=0.1424, Y_ERROR (tangential)=0.1499, Collision-Ped=0.40% (+5.09%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=2.98%, Collision-Veh2=nan%, Collision-Map2=0.00%, APD=0.3897, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=15.87ms (FPS=63.00 Hz)

[20260226_test_192931_DL4|test|I|Feb26 19:35:18|0:05:46.795413] Overall on ETH datasets: Accuracy=94.33%, ADE=0.3577, FDE=0.6885, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=1.10% (+1.22%), Collision-Veh=nan% (+nan%), Collision-Map=0.04% (+0.01%), Collision-Ped2=2.27%, Collision-Veh2=nan%, Collision-Map2=0.07%, APD=0.6841, AvgLen=6.3098, PedNum=7.7023, VehNum=0.0000, RolloutTime=15.32ms (FPS=65.26 Hz)
[20260226_test_192931_DL4|test|I|Feb26 19:35:18|0:05:46.796095] Overall on GC datasets: Accuracy=91.59%, ADE=0.2663, FDE=0.4743, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=-7.43% (+9.78%), Collision-Veh=nan% (+nan%), Collision-Map=-1.81% (+13.23%), Collision-Ped2=1.45%, Collision-Veh2=nan%, Collision-Map2=1.71%, APD=0.5300, AvgLen=3.1655, PedNum=44.0125, VehNum=0.0000, RolloutTime=15.39ms (FPS=64.96 Hz)
[20260226_test_192931_DL4|test|I|Feb26 19:35:18|0:05:46.796548] Overall on SDD datasets: Accuracy=91.00%, ADE=0.4350, FDE=0.8268, X_ERROR (normal)=0.6335, Y_ERROR (tangential)=0.9716, Collision-Ped=0.02% (+0.38%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=0.35%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4227, AvgLen=4.8309, PedNum=4.2814, VehNum=7.5732, RolloutTime=16.59ms (FPS=60.27 Hz)
[20260226_test_192931_DL4|test|I|Feb26 19:35:18|0:05:46.796981] Overall on UCY datasets: Accuracy=93.01%, ADE=0.2907, FDE=0.5786, X_ERROR (normal)=nan, Y_ERROR (tangential)=nan, Collision-Ped=3.68% (+0.82%), Collision-Veh=nan% (+nan%), Collision-Map=nan% (+nan%), Collision-Ped2=4.39%, Collision-Veh2=nan%, Collision-Map2=nan%, APD=0.4690, AvgLen=4.1614, PedNum=11.7884, VehNum=0.0000, RolloutTime=13.21ms (FPS=75.70 Hz)
[20260226_test_192931_DL4|test|I|Feb26 19:35:18|0:05:46.798228] Overall on WayMo datasets: Accuracy=95.03%, ADE=0.2654, FDE=0.5256, X_ERROR (normal)=0.1700, Y_ERROR (tangential)=0.1752, Collision-Ped=-0.25% (+5.09%), Collision-Veh=nan% (+nan%), Collision-Map=0.00% (+0.00%), Collision-Ped2=2.59%, Collision-Veh2=nan%, Collision-Map2=0.00%, APD=0.3323, AvgLen=5.3405, PedNum=6.4097, VehNum=3.7662, RolloutTime=16.17ms (FPS=61.83 Hz)

# %%
import json
from argparse import Namespace
from src.dataset import *
args = Namespace(**json.load(open('logs/train/All/args.json', 'r')))
dataset_list = []
dataset_list += ETHDataset.load_data_batch(args, "./data/ETH/")
dataset_list += UCYDataset.load_data_batch(args, "./data/UCY/data/")
dataset_list += [GCDataset.load_data(args, "./data/GC/Annotation")]
dataset_list += SDDDataset.load_data_batch(args, "./data/SDD/annotations/")
dataset_list += WayMoDataset.load_data_batch(args, "./data/WayMo/Processed/", total=500)
map_size = {dataset.name: dataset.map_data.map.size for dataset in dataset_list}

# %%
import pandas as pd
from pathlib import Path

path = Path('logs/train/All/records.jsonl')
test_record = pd.read_json(path, lines=True).iloc[-1]
df = pd.DataFrame(dict(dataset_names=test_record['dataset_names'], rollout_time=test_record['rollout_time']))
df['dataset_names'] = df['dataset_names'].apply(lambda x: x.removesuffix('_20test').removesuffix('_80test'))
df['map_size'] = df['dataset_names'].apply(lambda x: map_size[x])
df['rollout_time_ms'] = df['rollout_time'] * 1000
df
# Out:
#                  dataset_names  rollout_time  map_size  rollout_time_ms
# 0                          eth      0.023524       825        23.524118
# 1                        hotel      0.012877       192        12.877379
# 2                           GC      0.016010      3808        16.009694
# 3                  bookstore-4      0.015147      3618        15.147208
# 4                  bookstore-5      0.016758      1428        16.757556
# ..                         ...           ...       ...              ...
# 510  00023_67_706b16531a1e88ad      0.017717     26931        17.716865
# 511   00023_8_3422d65a6709ae25      0.024300     32204        24.300396
# 512  00024_11_178eadc469c471ee      0.018336     29141        18.336197
# 513  00024_17_1ffc7ba52f24095c      0.017066     32760        17.066399
# 514    00024_1_c84e0acafd54e0b      0.024436     39245        24.435957
#
# [515 rows x 4 columns]

# %%
import pandas as pd
from pathlib import Path

path = Path('logs/train/All_wo_Latent_Query/records.jsonl')
test_record2 = pd.read_json(path, lines=True).iloc[-1]
df2 = pd.DataFrame(dict(dataset_names=test_record2['dataset_names'], rollout_time=test_record2['rollout_time']))
df2['dataset_names'] = df['dataset_names'].apply(lambda x: x.removesuffix('_20test').removesuffix('_80test'))
df2['map_size'] = df['dataset_names'].apply(lambda x: map_size[x])
df2['rollout_time_ms'] = df2['rollout_time'] * 1000
df2
# Out:
#                  dataset_names  rollout_time  map_size  rollout_time_ms
# 0                          eth      0.016150       825        16.149549
# 1                        hotel      0.014466       192        14.466254
# 2                           GC      0.022506      3808        22.506104
# 3                  bookstore-4      0.019509      3618        19.509305
# 4                  bookstore-5      0.015316      1428        15.315502
# ..                         ...           ...       ...              ...
# 510  00023_67_706b16531a1e88ad      0.038212     26931        38.212001
# 511   00023_8_3422d65a6709ae25      0.042294     32204        42.294304
# 512  00024_11_178eadc469c471ee      0.040465     29141        40.465355
# 513  00024_17_1ffc7ba52f24095c      0.041186     32760        41.186114
# 514    00024_1_c84e0acafd54e0b      0.048070     39245        48.069537
#
# [515 rows x 4 columns]

# %%
from src.utils.plot import get_fig
import matplotlib.pyplot as plt
import seaborn as sns

fi, fig, axes = get_fig(1, 1, AW=4, AH=4)
ax = axes[0]

sns.scatterplot(data=df, x='map_size', y=df['rollout_time_ms'], s=1, label='w/ Latent Query')
sns.scatterplot(data=df2, x='map_size', y=df2['rollout_time_ms'], s=1, label='w/o Latent Query')
ax.axhline(y=30, color='r', linestyle='--')
ax.text(100000, 30, '30ms', color='r', va='bottom', ha='left')
ax.legend(markerscale=3, handletextpad=0, frameon=False)
ax.set_xlabel('Map Size (pixels)')
ax.set_ylabel('Rollout Time (ms)')
# Out:
# Text(0, 0.5, 'Rollout Time (ms)')
