# %%
import os
if os.getcwd().endswith('scripts'):
    os.chdir('..')
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: /data6/yuzihan/WorkSpace/35-HuaweiCrowdSimulation/HuaweiCrowdSimulationCode

# %%
import matplotlib.pyplot as plt
from argparse import Namespace
from src.utils.logger import init_logger
from src.utils.plot import get_fig

init_logger('src')
args = Namespace(
    cache_dataset=True, # False,
    fps=2.5,
    dot_per_meter=5,
    hist_step=8,
    pred_step=1,
    roll_step=12,
    skip_step=1,
)

# %%
from src.dataset import SDDDataset
args.cache_dataset = True
dataset = SDDDataset.load_data(args, 'data/SDD/annotations/bookstore/video1/annotations.txt')
fi, fig, axes = get_fig(1, 1, AW=6, AH=6, dpi=300)
ax = axes[0]
ax.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
ax.set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    ax.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# [None|sdd_dataset|I|Oct11 07:29:38|0:00:02.585202] Loading cached dataset from data/.cache/bookstore-1_2.5_8_1_1.pkl
# /tmp/ipykernel_2034446/3730391305.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
from src.dataset import SDDDataset
args.cache_dataset = True
dataset = SDDDataset.load_data(args, 'data/SDD/annotations/deathCircle/video1/annotations.txt')
fi, fig, axes = get_fig(1, 1, AW=6, AH=6, dpi=300)
ax = axes[0]
ax.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
ax.set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    ax.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# [None|sdd_dataset|I|Oct11 07:30:13|0:00:38.039061] Loading cached dataset from data/.cache/deathCircle-1_2.5_8_1_1.pkl
# /tmp/ipykernel_2034446/3650986681.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
from src.dataset import UCYDataset
dataset = UCYDataset.load_data(args, 'data/UCY/data/data_university_students/students003.vsp')
get_fig(1, 1, AW=6, AH=6, dpi=300)
plt.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
plt.gca().set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    plt.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# [None|ucy_dataset|I|Oct11 07:29:39|0:00:03.427945] Loading cached dataset from data/.cache/university_students-students003_2.5_8_1_1.pkl
# /tmp/ipykernel_2034446/3156693140.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
from src.dataset import UCYDataset
dataset = UCYDataset.load_data(args, 'data/UCY/data/data_zara/crowds_zara03.vsp')
get_fig(1, 1, AW=6, AH=6, dpi=300)
plt.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
plt.gca().set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    plt.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# [None|ucy_dataset|I|Oct11 07:29:40|0:00:04.393439] Loading cached dataset from data/.cache/zara-crowds_zara03_2.5_8_1_1.pkl
# /tmp/ipykernel_2034446/2241021414.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
from src.dataset import ETHDataset
dataset = ETHDataset.load_data(args, 'data/ETH/seq_eth/obsmat.txt')
get_fig(1, 1, AW=6, AH=6, dpi=300)
plt.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
plt.gca().set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    plt.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# [None|eth_dataset|I|Oct11 07:29:40|0:00:05.001885] Loading cached dataset from data/.cache/eth_2.5_8_1_1.pkl
# /tmp/ipykernel_2034446/747947292.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
from src.dataset import ETHDataset
dataset = ETHDataset.load_data(args, 'data/ETH/seq_hotel/obsmat.txt')
get_fig(1, 1, AW=6, AH=6, dpi=300)
plt.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
plt.gca().set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    plt.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# [None|eth_dataset|I|Oct11 07:29:41|0:00:05.714009] Loading cached dataset from data/.cache/hotel_2.5_8_1_1.pkl
# /tmp/ipykernel_2034446/1339755210.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
from src.dataset import GCDataset
dataset = GCDataset.load_data(args, 'data/GC/Annotation')
fi, fig, axes = get_fig(1, 1, AW=6, AH=6, dpi=300)
ax = axes[0]
ax.set_facecolor('#b2bec3')
ax.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    ax.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# [None|gc_dataset|I|Oct11 07:29:42|0:00:06.432099] Loading cached dataset from data/.cache/GC_2.5_8_1_1.pkl
# /tmp/ipykernel_2034446/2277525262.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
from src.dataset import WayMoDataset
args.cache_dataset = False
# dataset = WayMoDataset.load_data(args, 'data/WayMo/Processed/00000_10_2bc07893b2abbb07/data.csv.gz')
dataset = WayMoDataset.load_data(args, 'data/WayMo/Processed/00001_13_2e4be3a95170a8c/data.csv.gz')
get_fig(1, 1, AW=6, AH=6, dpi=300)
plt.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
plt.gca().set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    if group['type'].iloc[0] == 'pedestrian':
        plt.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
    else:
        plt.plot(group['x'], group['y'], color='blue')
# Out:
# [None|base_dataset|I|Oct23 22:55:54|0:04:01.688981] Normalized x with mean=8722.0451, std=1.0000
# [None|base_dataset|I|Oct23 22:55:54|0:04:01.691880] Normalized y with mean=10938.4759, std=1.0000
# [None|base_dataset|I|Oct23 22:55:54|0:04:01.692786] Normalized map into xmin=-83.6665, xmax=82.0375, ymin=-86.6502, ymax=101.2060
# 100%|██████████| 29/29 [00:00<00:00, 46.17it/s]
# [None|waymo_dataset|I|Oct23 22:55:55|0:04:02.326413] Caching dataset to data/.cache/00000_10_2bc07893b2abbb07_2.5_8_1_1.pkl
# [None|base_dataset|I|Oct23 22:55:56|0:04:04.186017] Normalized x with mean=2041.4553, std=1.0000
# [None|base_dataset|I|Oct23 22:55:56|0:04:04.187754] Normalized y with mean=-2648.8931, std=1.0000
# [None|base_dataset|I|Oct23 22:55:56|0:04:04.188652] Normalized map into xmin=-74.3147, xmax=68.7429, ymin=-78.5858, ymax=69.3388
# 100%|██████████| 29/29 [00:00<00:00, 54.40it/s]
# ...
