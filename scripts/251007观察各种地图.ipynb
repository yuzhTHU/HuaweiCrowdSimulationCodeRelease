# %%
import os
if os.getcwd().endswith('scripts'):
    os.chdir('..')
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: c:\Users\YuMeow\WorkSpace\35-HuaweiCrowdSimulation\HuaweiCrowdSimulationCode

# %%
import matplotlib.pyplot as plt
from argparse import Namespace
from src.utils.logger import init_logger

init_logger('src')
args = Namespace(
    cache_dataset=True, # False,
    fps=2.5,
    dot_per_meter=5,
    hist_step=8,
    pred_step=1,
    roll_step=12,
    skip_step=1,
)

# %%
from src.dataset import SDDDataset
dataset = SDDDataset.load_data(args, 'data/SDD/annotations/bookstore/video3/annotations.txt')
plt.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
plt.gca().set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    plt.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# [None|sdd_dataset|N|Oct07 14:23:15|0:00:00.000064] Loading cached dataset from data\.cache\bookstore-3_2.5_8_1_1.pkl
# C:\Users\YuMeow\AppData\Local\Temp\ipykernel_12532\887799106.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
from src.dataset import UCYDataset
dataset = UCYDataset.load_data(args, 'data/UCY/data/data_university_students/students003.vsp')
plt.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
plt.gca().set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    plt.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# [None|ucy_dataset|N|Oct07 14:24:45|0:01:30.049055] Loading cached dataset from data\.cache\university_students-students003_2.5_8_1_1.pkl
# C:\Users\YuMeow\AppData\Local\Temp\ipykernel_12532\1402145114.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
from src.dataset import UCYDataset
dataset = UCYDataset.load_data(args, 'data/UCY/data/data_university_students/students001.vsp')
plt.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
plt.gca().set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    plt.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# [None|ucy_dataset|N|Oct07 14:24:44|0:01:28.466183] Loading cached dataset from data\.cache\university_students-students001_2.5_8_1_1.pkl
# C:\Users\YuMeow\AppData\Local\Temp\ipykernel_12532\2818242103.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
from src.dataset import ETHDataset
dataset = ETHDataset.load_data(args, 'data/ETH/seq_eth/obsmat.txt')
plt.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
plt.gca().set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    plt.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# [None|base_dataset|I|Oct07 14:24:59|0:01:43.562385] Normalized x with mean=5.2178, std=1.0000
# [None|base_dataset|I|Oct07 14:24:59|0:01:43.563384] Normalized y with mean=5.3164, std=1.0000
# [None|base_dataset|I|Oct07 14:24:59|0:01:43.563384] Normalized map into xmin=-15.3125, xmax=9.4626, ymin=-16.2576, ymax=15.8446
# [None|eth_dataset|I|Oct07 14:26:05|0:02:49.249927] Caching dataset to data\.cache\eth_2.5_8_1_1.pkl
# C:\Users\YuMeow\AppData\Local\Temp\ipykernel_12532\3323692352.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
from src.dataset import ETHDataset
dataset = ETHDataset.load_data(args, 'data/ETH/seq_hotel/obsmat.txt')
plt.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
plt.gca().set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    plt.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# [None|base_dataset|I|Oct07 14:26:16|0:03:00.567857] Normalized x with mean=1.3930, std=1.0000
# [None|base_dataset|I|Oct07 14:26:16|0:03:00.569859] Normalized y with mean=-2.9774, std=1.0000
# [None|base_dataset|I|Oct07 14:26:16|0:03:00.569859] Normalized map into xmin=-7.5274, xmax=4.2880, ymin=-7.4213, ymax=8.3498
# [None|eth_dataset|I|Oct07 14:27:24|0:04:08.649114] Caching dataset to data\.cache\hotel_2.5_8_1_1.pkl
# C:\Users\YuMeow\AppData\Local\Temp\ipykernel_12532\4030859683.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
from src.dataset import GCDataset
dataset = GCDataset.load_data(args, 'data/GC/Annotation')
plt.imshow(dataset.map_data.map, extent=(dataset.map_data.xmin, dataset.map_data.xmax, dataset.map_data.ymin, dataset.map_data.ymax), origin='lower', cmap='gray_r')
plt.gca().set_facecolor('#b2bec3')
for pid, group in dataset.df_data.groupby('id'):
    cmap = plt.cm.get_cmap('viridis')
    plt.plot(group['x'], group['y'], color=cmap(group['f'].max() / dataset.df_data['f'].max()))
# Out:
# Load GC Data: 100%|██████████| 12684/12684 [01:42<00:00, 123.99it/s]
# [None|base_dataset|I|Oct07 14:30:05|0:06:49.585186] Normalized x with mean=14.0942, std=1.0000
# [None|base_dataset|I|Oct07 14:30:05|0:06:49.594186] Normalized y with mean=18.3459, std=1.0000
# [None|base_dataset|I|Oct07 14:30:05|0:06:49.595186] Normalized map into xmin=-32.3055, xmax=34.7790, ymin=-22.1568, ymax=33.0886
# [None|gc_dataset|I|Oct07 14:39:45|0:16:29.589707] Caching dataset to data\.cache\GC_2.5_8_1_1.pkl
# C:\Users\YuMeow\AppData\Local\Temp\ipykernel_12532\2828154507.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('viridis')
